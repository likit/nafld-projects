# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('2011-2012-health-data.csv')

# %%
dataset
# Out:
#           ServiceNo      ServiceDate  CustID   age  sex  cmsCode Weight  \
# 0      201101050001    5/1/2011 0:00   225.0  59.0  2.0  38468.0   81.8
# 1      201101050002    5/1/2011 0:00   225.0  55.0  2.0      0.0   53.7
# 2      201101050003    5/1/2011 0:00   225.0  60.0  2.0      0.0   57.2
# 3      201101050004    5/1/2011 0:00   225.0  55.0  2.0      0.0     60
# 4      201101050005    5/1/2011 0:00   225.0  59.0  1.0      0.0   79.6
# ...             ...              ...     ...   ...  ...      ...    ...
# 18640  201112280127  28/12/2011 0:00   216.0  30.0  1.0      0.0     67
# 18641  201112280128  28/12/2011 0:00   216.0  41.0  1.0      0.0     51
# 18642  201112280129  28/12/2011 0:00   216.0  38.0  1.0      0.0   69.7
# 18643  201112280130  28/12/2011 0:00   216.0  27.0  1.0      0.0     81
# 18644  201112280131  28/12/2011 0:00   216.0  45.0  1.0      0.0     63
#
#       Height HeartRate Systolic  Diastolic          BMI   HDL     TG    UA
# 0        159        78      150       96.0  32.35631502  56.4  115.0  5.04
# 1        156        72      120       70.0  22.06607495  73.7  141.0  3.82
# 2        156        72      110       70.0   23.5042735  77.5   69.0  5.01
# 3        157        76      120       80.0  24.34175829  77.9   79.0  2.83
# 4      171.5        68      130       70.0  27.06355345  60.4   94.0  5.82
# ...      ...       ...      ...        ...          ...   ...    ...   ...
# 18640    171        64      130       80.0  22.91303307  37.3  101.0  6.28
# 18641    163        80      130       80.0   19.1953028    68   55.0  4.56
# 18642    161        70      110       70.0   26.8893947  41.8   97.0  6.34
# 18643  169.5        72      130       80.0   28.1932806  45.2   84.0  6.12
# 18644    163        64      110       70.0  23.71184463    49   71.0  5.76
#
# [18645 rows x 15 columns]

# %%
dataset = dataset.set_index('ServiceNo')

# %%
dataset
# Out:
#                   ServiceDate  CustID   age  sex  cmsCode Weight Height  \
# ServiceNo
# 201101050001    5/1/2011 0:00   225.0  59.0  2.0  38468.0   81.8    159
# 201101050002    5/1/2011 0:00   225.0  55.0  2.0      0.0   53.7    156
# 201101050003    5/1/2011 0:00   225.0  60.0  2.0      0.0   57.2    156
# 201101050004    5/1/2011 0:00   225.0  55.0  2.0      0.0     60    157
# 201101050005    5/1/2011 0:00   225.0  59.0  1.0      0.0   79.6  171.5
# ...                       ...     ...   ...  ...      ...    ...    ...
# 201112280127  28/12/2011 0:00   216.0  30.0  1.0      0.0     67    171
# 201112280128  28/12/2011 0:00   216.0  41.0  1.0      0.0     51    163
# 201112280129  28/12/2011 0:00   216.0  38.0  1.0      0.0   69.7    161
# 201112280130  28/12/2011 0:00   216.0  27.0  1.0      0.0     81  169.5
# 201112280131  28/12/2011 0:00   216.0  45.0  1.0      0.0     63    163
#
#              HeartRate Systolic  Diastolic          BMI   HDL     TG    UA
# ServiceNo
# 201101050001        78      150       96.0  32.35631502  56.4  115.0  5.04
# 201101050002        72      120       70.0  22.06607495  73.7  141.0  3.82
# 201101050003        72      110       70.0   23.5042735  77.5   69.0  5.01
# 201101050004        76      120       80.0  24.34175829  77.9   79.0  2.83
# 201101050005        68      130       70.0  27.06355345  60.4   94.0  5.82
# ...                ...      ...        ...          ...   ...    ...   ...
# 201112280127        64      130       80.0  22.91303307  37.3  101.0  6.28
# 201112280128        80      130       80.0   19.1953028    68   55.0  4.56
# 201112280129        70      110       70.0   26.8893947  41.8   97.0  6.34
# 201112280130        72      130       80.0   28.1932806  45.2   84.0  6.12
# 201112280131        64      110       70.0  23.71184463    49   71.0  5.76
#
# [18645 rows x 14 columns]

# %%
dataset.dtypes
# Out:
# ServiceDate     object
# CustID         float64
# age            float64
# sex            float64
# cmsCode        float64
# Weight          object
# Height          object
# HeartRate       object
# Systolic        object
# Diastolic      float64
# BMI             object
# HDL             object
# TG             float64
# UA             float64
# dtype: object

# %%
dataset.BMI = pd.to_numeric(dataset.BMI, errors='coerce')
dataset.Systolic = pd.to_numeric(dataset.Systolic, errors='coerce')
dataset.HeartRate = pd.to_numeric(dataset.HeartRate, errors='coerce')
dataset.Weight = pd.to_numeric(dataset.Weight, errors='coerce')
dataset.Height = pd.to_numeric(dataset.Height, errors='coerce')
dataset.HDL = pd.to_numeric(dataset.HDL, errors='coerce')

# %%
dataset.dtypes
# Out:
# ServiceDate     object
# CustID         float64
# age            float64
# sex            float64
# cmsCode        float64
# Weight         float64
# Height         float64
# HeartRate      float64
# Systolic       float64
# Diastolic      float64
# BMI            float64
# HDL            float64
# TG             float64
# UA             float64
# dtype: object

# %%
dataset.describe()
# Out:
#              CustID           age           sex        cmsCode        Weight  \
# count  18639.000000  18639.000000  18534.000000   17902.000000  17245.000000
# mean     114.119105     46.725093      1.591454   16342.664618     62.679913
# std       74.614742     13.791772      0.491578   20330.214235     13.251206
# min        1.000000      0.000000      1.000000       0.000000     32.500000
# 25%       53.000000     38.000000      1.000000       0.000000     53.000000
# 50%      104.000000     49.000000      2.000000       0.000000     61.000000
# 75%      179.000000     58.000000      2.000000   40753.750000     70.000000
# max      259.000000     93.000000      2.000000  158637.000000    190.000000
#
#              Height     HeartRate      Systolic     Diastolic           BMI  \
# count  17255.000000  16143.000000  16170.000000  16170.000000  17234.000000
# mean     161.418383     77.168990    121.077860     77.275758     23.962853
# std        8.147665      9.734707     13.530711      9.129945      4.231036
# min      136.000000      6.000000     80.000000     50.000000     13.888353
# 25%      155.000000     72.000000    110.000000     70.000000     20.962529
# 50%      161.000000     78.000000    120.000000     80.000000     23.433745
# 75%      167.000000     82.000000    130.000000     80.000000     26.229508
# max      193.000000    890.000000    226.000000    150.000000     75.384228
#
#                 HDL            TG            UA
# count  15195.000000  15254.000000  13476.000000
# mean      62.672004    121.128294      5.378511
# std       16.861962     92.709515      1.454883
# min       16.100000     21.000000      0.660000
# 25%       50.400000     70.000000      4.300000
# 50%       60.800000     98.000000      5.200000
# 75%       72.900000    143.000000      6.300000
# max      163.300000   1877.000000     13.140000

# %%
dataset.count()
# Out:
# ServiceDate    18645
# CustID         18639
# age            18639
# sex            18534
# cmsCode        17902
# Weight         17245
# Height         17255
# HeartRate      16143
# Systolic       16170
# Diastolic      16170
# BMI            17234
# HDL            15195
# TG             15254
# UA             13476
# dtype: int64

# %%
dataset = dataset.dropna()

# %%
dataset.count()
# Out:
# ServiceDate    12126
# CustID         12126
# age            12126
# sex            12126
# cmsCode        12126
# Weight         12126
# Height         12126
# HeartRate      12126
# Systolic       12126
# Diastolic      12126
# BMI            12126
# HDL            12126
# TG             12126
# UA             12126
# dtype: int64

# %%
dataset['TGtoHDL'] = dataset.TG/dataset.HDL
# Out:
# /var/folders/6m/y4cnh6_n3wdcwwtbc5lbmlm80000gn/T/ipykernel_92194/610475846.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['TGtoHDL'] = dataset.TG/dataset.HDL

# %%
dataset
# Out:
#                   ServiceDate  CustID   age  sex  cmsCode  Weight  Height  \
# ServiceNo
# 201101050001    5/1/2011 0:00   225.0  59.0  2.0  38468.0    81.8   159.0
# 201101050002    5/1/2011 0:00   225.0  55.0  2.0      0.0    53.7   156.0
# 201101050003    5/1/2011 0:00   225.0  60.0  2.0      0.0    57.2   156.0
# 201101050004    5/1/2011 0:00   225.0  55.0  2.0      0.0    60.0   157.0
# 201101050005    5/1/2011 0:00   225.0  59.0  1.0      0.0    79.6   171.5
# ...                       ...     ...   ...  ...      ...     ...     ...
# 201112280127  28/12/2011 0:00   216.0  30.0  1.0      0.0    67.0   171.0
# 201112280128  28/12/2011 0:00   216.0  41.0  1.0      0.0    51.0   163.0
# 201112280129  28/12/2011 0:00   216.0  38.0  1.0      0.0    69.7   161.0
# 201112280130  28/12/2011 0:00   216.0  27.0  1.0      0.0    81.0   169.5
# 201112280131  28/12/2011 0:00   216.0  45.0  1.0      0.0    63.0   163.0
#
#               HeartRate  Systolic  Diastolic        BMI   HDL     TG    UA  \
# ServiceNo
# 201101050001       78.0     150.0       96.0  32.356315  56.4  115.0  5.04
# 201101050002       72.0     120.0       70.0  22.066075  73.7  141.0  3.82
# 201101050003       72.0     110.0       70.0  23.504274  77.5   69.0  5.01
# 201101050004       76.0     120.0       80.0  24.341758  77.9   79.0  2.83
# 201101050005       68.0     130.0       70.0  27.063553  60.4   94.0  5.82
# ...                 ...       ...        ...        ...   ...    ...   ...
# 201112280127       64.0     130.0       80.0  22.913033  37.3  101.0  6.28
# 201112280128       80.0     130.0       80.0  19.195303  68.0   55.0  4.56
# 201112280129       70.0     110.0       70.0  26.889395  41.8   97.0  6.34
# 201112280130       72.0     130.0       80.0  28.193281  45.2   84.0  6.12
# 201112280131       64.0     110.0       70.0  23.711845  49.0   71.0  5.76
#
#                TGtoHDL
# ServiceNo
# 201101050001  2.039007
# 201101050002  1.913161
# 201101050003  0.890323
# 201101050004  1.014121
# 201101050005  1.556291
# ...                ...
# 201112280127  2.707775
# 201112280128  0.808824
# 201112280129  2.320574
# 201112280130  1.858407
# 201112280131  1.448980
#
# [12126 rows x 15 columns]

# %%
pd.plotting.scatter_matrix(dataset[['age', 'Weight', 'HDL', 'TG', 'Systolic', 'UA', 'BMI', 'TGtoHDL']], figsize=(15,15))
# Out:
# array([[<Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='Weight', ylabel='age'>,
#         <Axes: xlabel='HDL', ylabel='age'>,
#         <Axes: xlabel='TG', ylabel='age'>,
#         <Axes: xlabel='Systolic', ylabel='age'>,
#         <Axes: xlabel='UA', ylabel='age'>,
#         <Axes: xlabel='BMI', ylabel='age'>,
#         <Axes: xlabel='TGtoHDL', ylabel='age'>],
#        [<Axes: xlabel='age', ylabel='Weight'>,
#         <Axes: xlabel='Weight', ylabel='Weight'>,
#         <Axes: xlabel='HDL', ylabel='Weight'>,
#         <Axes: xlabel='TG', ylabel='Weight'>,
#         <Axes: xlabel='Systolic', ylabel='Weight'>,
#         <Axes: xlabel='UA', ylabel='Weight'>,
#         <Axes: xlabel='BMI', ylabel='Weight'>,
#         <Axes: xlabel='TGtoHDL', ylabel='Weight'>],
#        [<Axes: xlabel='age', ylabel='HDL'>,
#         <Axes: xlabel='Weight', ylabel='HDL'>,
#         <Axes: xlabel='HDL', ylabel='HDL'>,
#         <Axes: xlabel='TG', ylabel='HDL'>,
#         <Axes: xlabel='Systolic', ylabel='HDL'>,
#         <Axes: xlabel='UA', ylabel='HDL'>,
#         <Axes: xlabel='BMI', ylabel='HDL'>,
#         <Axes: xlabel='TGtoHDL', ylabel='HDL'>],
#        [<Axes: xlabel='age', ylabel='TG'>,
#         <Axes: xlabel='Weight', ylabel='TG'>,
#         <Axes: xlabel='HDL', ylabel='TG'>,
#         <Axes: xlabel='TG', ylabel='TG'>,
#         <Axes: xlabel='Systolic', ylabel='TG'>,
#         <Axes: xlabel='UA', ylabel='TG'>,
#         <Axes: xlabel='BMI', ylabel='TG'>,
#         <Axes: xlabel='TGtoHDL', ylabel='TG'>],
#        [<Axes: xlabel='age', ylabel='Systolic'>,
#         <Axes: xlabel='Weight', ylabel='Systolic'>,
#         <Axes: xlabel='HDL', ylabel='Systolic'>,
#         <Axes: xlabel='TG', ylabel='Systolic'>,
#         <Axes: xlabel='Systolic', ylabel='Systolic'>,
#         <Axes: xlabel='UA', ylabel='Systolic'>,
#         <Axes: xlabel='BMI', ylabel='Systolic'>,
#         <Axes: xlabel='TGtoHDL', ylabel='Systolic'>],
#        [<Axes: xlabel='age', ylabel='UA'>,
#         <Axes: xlabel='Weight', ylabel='UA'>,
#         <Axes: xlabel='HDL', ylabel='UA'>,
#         <Axes: xlabel='TG', ylabel='UA'>,
#         <Axes: xlabel='Systolic', ylabel='UA'>,
#         <Axes: xlabel='UA', ylabel='UA'>,
#         <Axes: xlabel='BMI', ylabel='UA'>,
#         <Axes: xlabel='TGtoHDL', ylabel='UA'>],
#        [<Axes: xlabel='age', ylabel='BMI'>,
#         <Axes: xlabel='Weight', ylabel='BMI'>,
#         <Axes: xlabel='HDL', ylabel='BMI'>,
#         <Axes: xlabel='TG', ylabel='BMI'>,
#         <Axes: xlabel='Systolic', ylabel='BMI'>,
#         <Axes: xlabel='UA', ylabel='BMI'>,
#         <Axes: xlabel='BMI', ylabel='BMI'>,
#         <Axes: xlabel='TGtoHDL', ylabel='BMI'>],
#        [<Axes: xlabel='age', ylabel='TGtoHDL'>,
#         <Axes: xlabel='Weight', ylabel='TGtoHDL'>,
#         <Axes: xlabel='HDL', ylabel='TGtoHDL'>,
#         <Axes: xlabel='TG', ylabel='TGtoHDL'>,
#         <Axes: xlabel='Systolic', ylabel='TGtoHDL'>,
#         <Axes: xlabel='UA', ylabel='TGtoHDL'>,
#         <Axes: xlabel='BMI', ylabel='TGtoHDL'>,
#         <Axes: xlabel='TGtoHDL', ylabel='TGtoHDL'>]], dtype=object)

# %% [markdown]
# ## Linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
features = ['UA', 'sex']

# %%
X = dataset.loc[:, features]

# %%
y = dataset.BMI

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Training set score: {:.2f}'.format(lr.score(X_train, y_train)))
print('Test set score: {:.2f}'.format(lr.score(X_test, y_test)))
# Out:
# Training set score: 0.12
# Test set score: 0.13

# %%
lr.coef_
# Out:
# array([1.0745552 , 0.63733809])

# %%
lr.predict([[7.0, 1]])
# Out:
# /Users/likit/opt/anaconda3/envs/adv-comhealth/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([25.57114858])
